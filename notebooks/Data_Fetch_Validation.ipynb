# %%
import pandas as pd
df = pd.read_csv("../data/AAPL_1Day.csv")
print(df.head())
print("Rows:", len(df))
# Out:
#   symbol                         ts    open    high     low   close  \
# 0   AAPL  2018-01-02 05:00:00+00:00  170.16  172.30  169.26  172.26
# 1   AAPL  2018-01-03 05:00:00+00:00  172.53  174.55  171.96  172.23
# 2   AAPL  2018-01-04 05:00:00+00:00  172.54  173.47  172.08  173.03
# 3   AAPL  2018-01-05 05:00:00+00:00  173.44  175.37  173.05  175.00
# 4   AAPL  2018-01-08 05:00:00+00:00  174.35  175.61  173.93  174.35
#
#        volume        vwap    trades
# 0  27641744.0  171.378702  177088.0
# 1  31760108.0  173.068527  188340.0
# 2  24390260.0  172.987175  153154.0
# 3  26239861.0  174.686561  152077.0
# 4  22729369.0  174.610658  138848.0
# Rows: 1976
